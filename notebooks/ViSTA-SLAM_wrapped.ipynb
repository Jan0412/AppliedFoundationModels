# %% [markdown]
# # Reconstructor: ViSTA-SLAM

# %% [markdown]
# ### Environment Context
# Force the working directory to the repository root to ensure configuration files and submodules resolve correctly.

# %%
import os
from pathlib import Path

# Force the working directory to the repository root
if Path.cwd().name == "notebooks":
    os.chdir("..")

# Verify context is now repository root
print(f"Current Working Directory: {Path.cwd()}")

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # Invoking ViSTA-SLAM reconstructor

# %% [markdown]
# ### WORKSTATION:

# %% [markdown]
# **Note**: Compiled binaries tested on following workstations:
# - atcremers71

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # DATASET: tum_rgbd

# %%
input_sequence_dir = Path("/storage/group/dataset_mirrors/tum_rgbd_benchmark/rgbd_dataset_freiburg1_room/rgb")

# %%
output_results_dir = Path("data/reconstruction/vista_slam_output/tum_rgbd_benchmark/rgbd_dataset_freiburg1_room")

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # DATASET: ScanNet

# %% [markdown]
# ---

# %% [markdown]
# ## scene0000_00:
# sceneType = Apartment
#
# numColorFrames = 5578

# %%
input_sequence_dir = Path("/storage/group/dataset_mirrors/scannet/scans/scene0000_00/color")

# %%
output_results_dir = Path("data/reconstruction/vista_slam_output/scannet/scene0000_00")

# %% [markdown]
# ---

# %% [markdown]
# ## scene0001_00:
# sceneType = Living room / Lounge
#
# numColorFrames = 1545

# %%
input_sequence_dir = Path("/storage/group/dataset_mirrors/scannet/scans/scene0001_00/color")

# %%
output_results_dir = Path("data/reconstruction/vista_slam_output/scannet/scene0001_00")

# %% [markdown]
# ---

# %% [markdown]
# ## scene0002_00:
# sceneType = Living room / Lounge
#
# numColorFrames = 5193

# %%
input_sequence_dir = Path("/storage/group/dataset_mirrors/scannet/scans/scene0002_00/color")

# %%
output_results_dir = Path("data/reconstruction/vista_slam_output/scannet/scene0002_00")

# %% [markdown]
# ---

# %% [markdown]
# ## scene0003_00:
# sceneType = Kitchen
#
# numColorFrames = 1736

# %%
input_sequence_dir = Path("/storage/group/dataset_mirrors/scannet/scans/scene0003_00/color")

# %%
output_results_dir = Path("data/reconstruction/vista_slam_output/scannet/scene0003_00")

# %% [markdown]
# ---

# %% [markdown]
# ## scene0004_00:
# sceneType = Hallway
#
# numColorFrames = 929

# %%
input_sequence_dir = Path("/storage/group/dataset_mirrors/scannet/scans/scene0004_00/color")

# %%
output_results_dir = Path("data/reconstruction/vista_slam_output/scannet/scene0004_00")

# %% [markdown]
# ---
# ---
# ---

# %%
from src.models.reconstructors.vista_slam import ViSTASLAMReconstructor

# 1. Instantiate from the global config file
reconstructor = ViSTASLAMReconstructor.from_config("config.yaml")

# %%
# 2. Invoke the reconstructor
reconstructor.invoke(
    input_dir=input_sequence_dir,
    output_dir=output_results_dir
)
